# %%
import pandas as pd

# %%
covid = pd.read_csv('covid19_dataset.csv')

# %%
#having a glance at some of the records
covid.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0        1803.987              NaN                597.029
# 1        1803.987              NaN                597.029
# 2        1803.987              NaN                597.029
# 3        1803.987              NaN                597.029
# 4        1803.987              NaN                597.029
#
#    diabetes_prevalence  female_smokers  male_smokers  handwashing_facilities  \
# 0                 9.59             NaN           NaN                  37.746
# 1                 9.59             NaN           NaN                  37.746
# 2                 9.59             NaN           NaN                  37.746
# 3                 9.59             NaN           NaN                  37.746
# 4                 9.59             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
# [5 rows x 59 columns]

# %%
covid.tail()
# Out:
#       iso_code continent  location        date  total_cases  new_cases  \
# 88144      ZWE    Africa  Zimbabwe  2021-05-09      38419.0        5.0
# 88145      ZWE    Africa  Zimbabwe  2021-05-10      38433.0       14.0
# 88146      ZWE    Africa  Zimbabwe  2021-05-11      38448.0       15.0
# 88147      ZWE    Africa  Zimbabwe  2021-05-12      38466.0       18.0
# 88148      ZWE    Africa  Zimbabwe  2021-05-13      38491.0       25.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 88144              19.714        1576.0         0.0                0.857  ...
# 88145              20.000        1576.0         0.0                0.429  ...
# 88146              17.286        1579.0         3.0                0.714  ...
# 88147              15.571        1579.0         0.0                0.714  ...
# 88148              13.286        1582.0         3.0                1.000  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 88144        1899.775             21.4                307.846
# 88145        1899.775             21.4                307.846
# 88146        1899.775             21.4                307.846
# 88147        1899.775             21.4                307.846
# 88148        1899.775             21.4                307.846
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 88144                 1.82             1.6          30.7
# 88145                 1.82             1.6          30.7
# 88146                 1.82             1.6          30.7
# 88147                 1.82             1.6          30.7
# 88148                 1.82             1.6          30.7
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 88144                  36.791                         1.7            61.49
# 88145                  36.791                         1.7            61.49
# 88146                  36.791                         1.7            61.49
# 88147                  36.791                         1.7            61.49
# 88148                  36.791                         1.7            61.49
#
#        human_development_index
# 88144                    0.571
# 88145                    0.571
# 88146                    0.571
# 88147                    0.571
# 88148                    0.571
#
# [5 rows x 59 columns]

# %%
covid.shape
# Out:
# (88149, 59)

# %%
covid.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'new_vaccinations',
#        'new_vaccinations_smoothed', 'total_vaccinations_per_hundred',
#        'people_vaccinated_per_hundred', 'people_fully_vaccinated_per_hundred',
#        'new_vaccinations_smoothed_per_million', 'stringency_index',
#        'population', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index'],
#       dtype='object')

# %%
#looking at different locations
covid['location'].value_counts()
# Out:
# Mexico       499
# Argentina    499
# Thailand     496
# Peru         494
# Taiwan       484
#             ...
# Aruba         45
# Curacao       45
# Nauru         23
# Tonga         22
# Tuvalu         1
# Name: location, Length: 223, dtype: int64

# %%
#description of categorical columns
covid.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  8.565900e+04   85657.000000        84656.000000  7.589600e+04
# mean   8.761911e+05    5975.084360         5977.454546  2.404931e+04
# std    6.046645e+06   37616.791902        37145.321057  1.425372e+05
# min    1.000000e+00  -74347.000000        -6223.000000  1.000000e+00
# 25%    9.970000e+02       2.000000            7.143000  4.700000e+01
# 50%    1.115400e+04      71.000000           88.143000  3.280000e+02
# 75%    1.181745e+05     782.000000          815.714000  3.187000e+03
# max    1.608330e+08  905992.000000       826374.286000  3.340394e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  76054.000000         84656.000000             85197.000000
# mean     141.091133           125.463275             10720.438759
# std      770.991615           708.505148             20378.357797
# min    -1918.000000          -232.143000                 0.001000
# 25%        0.000000             0.000000               212.378000
# 50%        2.000000             1.286000              1459.378000
# 75%       18.000000            14.000000             10524.687000
# max    17906.000000         14435.857000            174335.081000
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count           85195.000000                    84199.000000
# mean               75.515934                       75.489037
# std               191.065367                      151.285167
# min             -2153.437000                     -276.825000
# 25%                 0.197000                        1.197000
# 50%                 7.847000                       10.351000
# 75%                69.879000                       78.114500
# max             18293.675000                     4083.500000
#
#        total_deaths_per_million  ...  gdp_per_capita  extreme_poverty  \
# count              75447.000000  ...    79532.000000     54103.000000
# mean                 236.976196  ...    19142.782878        13.359429
# std                  414.634595  ...    19840.644707        19.946328
# min                    0.001000  ...      661.240000         0.100000
# 25%                    7.011000  ...     4466.507000         0.500000
# 50%                   42.419000  ...    12951.839000         2.200000
# 75%                  256.685000  ...    27216.445000        21.200000
# max                 2998.856000  ...   116935.600000        77.600000
#
#        cardiovasc_death_rate  diabetes_prevalence  female_smokers  \
# count           80095.000000         81527.000000    62739.000000
# mean              257.933736             7.864887       10.530982
# std               118.807435             4.055496       10.414020
# min                79.370000             0.990000        0.100000
# 25%               167.295000             5.290000        1.900000
# 50%               242.648000             7.110000        6.300000
# 75%               329.635000            10.080000       19.300000
# max               724.417000            30.530000       44.000000
#
#        male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# count  61816.000000            40242.000000                73070.000000
# mean      32.663521               50.896414                    3.029626
# std       13.473407               31.762144                    2.462342
# min        7.700000                1.188000                    0.100000
# 25%       21.600000               20.859000                    1.300000
# 50%       31.400000               49.839000                    2.400000
# 75%       41.100000               83.241000                    3.861000
# max       78.100000               98.999000                   13.800000
#
#        life_expectancy  human_development_index
# count     83717.000000             79971.000000
# mean         73.178443                 0.727039
# std           7.544177                 0.150063
# min          53.280000                 0.394000
# 25%          67.920000                 0.602000
# 50%          74.620000                 0.748000
# 75%          78.730000                 0.848000
# max          86.750000                 0.957000
#
# [8 rows x 54 columns]

# %%
#cheacking if columns have null values
covid.isnull().sum()
# Out:
# iso_code                                     0
# continent                                 4228
# location                                     0
# date                                         0
# total_cases                               2490
# new_cases                                 2492
# new_cases_smoothed                        3493
# total_deaths                             12253
# new_deaths                               12095
# new_deaths_smoothed                       3493
# total_cases_per_million                   2952
# new_cases_per_million                     2954
# new_cases_smoothed_per_million            3950
# total_deaths_per_million                 12702
# new_deaths_per_million                   12544
# new_deaths_smoothed_per_million           3950
# reproduction_rate                        17023
# icu_patients                             79143
# icu_patients_per_million                 79143
# hosp_patients                            76931
# hosp_patients_per_million                76931
# weekly_icu_admissions                    87333
# weekly_icu_admissions_per_million        87333
# weekly_hosp_admissions                   86734
# weekly_hosp_admissions_per_million       86734
# new_tests                                48192
# total_tests                              48495
# total_tests_per_thousand                 48495
# new_tests_per_thousand                   48192
# new_tests_smoothed                       42362
# new_tests_smoothed_per_thousand          42362
# positive_rate                            45009
# tests_per_case                           45603
# tests_units                              40878
# total_vaccinations                       77429
# people_vaccinated                        78134
# people_fully_vaccinated                  80591
# new_vaccinations                         79070
# new_vaccinations_smoothed                70637
# total_vaccinations_per_hundred           77429
# people_vaccinated_per_hundred            78134
# people_fully_vaccinated_per_hundred      80591
# new_vaccinations_smoothed_per_million    70637
# stringency_index                         13431
# population                                 580
# population_density                        6080
# median_age                                8793
# aged_65_older                             9695
# aged_70_older                             9236
# gdp_per_capita                            8617
# extreme_poverty                          34046
# cardiovasc_death_rate                     8054
# diabetes_prevalence                       6622
# female_smokers                           25410
# male_smokers                             26333
# handwashing_facilities                   47907
# hospital_beds_per_thousand               15079
# life_expectancy                           4432
# human_development_index                   8178
# dtype: int64

# %%
#getting the cases in india
india_case= covid[covid['location']=='India']

# %%
india_case.head()
# Out:
#       iso_code continent location        date  total_cases  new_cases  \
# 36268      IND      Asia    India  2020-01-30          1.0        1.0
# 36269      IND      Asia    India  2020-01-31          1.0        0.0
# 36270      IND      Asia    India  2020-02-01          1.0        0.0
# 36271      IND      Asia    India  2020-02-02          2.0        1.0
# 36272      IND      Asia    India  2020-02-03          3.0        1.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 36268                 NaN           NaN         NaN                  NaN  ...
# 36269                 NaN           NaN         NaN                  NaN  ...
# 36270                 NaN           NaN         NaN                  NaN  ...
# 36271                 NaN           NaN         NaN                  NaN  ...
# 36272                 NaN           NaN         NaN                  NaN  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 36268        6426.674             21.2                 282.28
# 36269        6426.674             21.2                 282.28
# 36270        6426.674             21.2                 282.28
# 36271        6426.674             21.2                 282.28
# 36272        6426.674             21.2                 282.28
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 36268                10.39             1.9          20.6
# 36269                10.39             1.9          20.6
# 36270                10.39             1.9          20.6
# 36271                10.39             1.9          20.6
# 36272                10.39             1.9          20.6
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 36268                   59.55                        0.53            69.66
# 36269                   59.55                        0.53            69.66
# 36270                   59.55                        0.53            69.66
# 36271                   59.55                        0.53            69.66
# 36272                   59.55                        0.53            69.66
#
#        human_development_index
# 36268                    0.645
# 36269                    0.645
# 36270                    0.645
# 36271                    0.645
# 36272                    0.645
#
# [5 rows x 59 columns]

# %%
india_case.tail()
# Out:
#       iso_code continent location        date  total_cases  new_cases  \
# 36733      IND      Asia    India  2021-05-09   22662575.0   366494.0
# 36734      IND      Asia    India  2021-05-10   22992517.0   329942.0
# 36735      IND      Asia    India  2021-05-11   23340938.0   348421.0
# 36736      IND      Asia    India  2021-05-12   23703665.0   362727.0
# 36737      IND      Asia    India  2021-05-13   23703665.0        0.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 36733          391008.286      246116.0      3769.0             3879.571  ...
# 36734          387097.714      249992.0      3876.0             3940.571  ...
# 36735          382279.857      254197.0      4205.0             4001.286  ...
# 36736          375179.286      258317.0      4120.0             4021.286  ...
# 36737          316009.571      258317.0         0.0             3462.000  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 36733        6426.674             21.2                 282.28
# 36734        6426.674             21.2                 282.28
# 36735        6426.674             21.2                 282.28
# 36736        6426.674             21.2                 282.28
# 36737        6426.674             21.2                 282.28
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 36733                10.39             1.9          20.6
# 36734                10.39             1.9          20.6
# 36735                10.39             1.9          20.6
# 36736                10.39             1.9          20.6
# 36737                10.39             1.9          20.6
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 36733                   59.55                        0.53            69.66
# 36734                   59.55                        0.53            69.66
# 36735                   59.55                        0.53            69.66
# 36736                   59.55                        0.53            69.66
# 36737                   59.55                        0.53            69.66
#
#        human_development_index
# 36733                    0.645
# 36734                    0.645
# 36735                    0.645
# 36736                    0.645
# 36737                    0.645
#
# [5 rows x 59 columns]

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
#total cases per day
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x='date',y='total_cases',data=india_case)
plt.show()

# %%
#making a dataframe for last 5 days
india_last_5_days=india_case.tail()

# %%
#total cases in last 5 days
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x='date',y='total_cases',data=india_last_5_days)
plt.show()

# %%
#total tests per day
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x='date',y='total_tests',data=india_case)
plt.show()

# %%
#total tests in last 5 days
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x='date',y='total_tests',data=india_last_5_days)
plt.show()

# %%
#we can do same analysis with other countries.

# %%
#Understanding cases of India,china and japan
india_japan_china=covid[(covid['location']=='India')|(covid['location']=='China')|(covid['location']=='Japan')]

# %%
#plotting growth of cases across China,India and Japan
#total tests in last 5 days
sns.set(rc={'figure.figsize':(15,10)})
sns.barplot(x='location',y='total_cases',data=india_japan_china, hue='date')
plt.show()

# %%
#understanding cases of germanyand spain
germany_spain=covid[(covid['location']=='Germany')|(covid['location']=='Spain')]

# %%
#plotting growth of cases across germany and spain
sns.set(rc={'figure.figsize':(15,10)})
sns.barplot(x='location',y='total_cases',data=germany_spain,hue='date')
plt.show()

# %%
#getting latest data
last_day_cases=covid[covid['date']=='2021-05-13']
last_day_cases
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 444         AFG      Asia  Afghanistan  2021-05-13      63045.0      327.0
# 900    OWID_AFR       NaN       Africa  2021-05-13    4666422.0     9443.0
# 1344        ALB    Europe      Albania  2021-05-13     131890.0       45.0
# 1788        DZA    Africa      Algeria  2021-05-13     124889.0      207.0
# 2226        AND    Europe      Andorra  2021-05-13      13470.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 86379       VNM      Asia      Vietnam  2021-05-13       3740.0       82.0
# 86907  OWID_WRL       NaN        World  2021-05-13  160833004.0   382131.0
# 87306       YEM      Asia        Yemen  2021-05-13       6507.0        9.0
# 87728       ZMB    Africa       Zambia  2021-05-13      92262.0       51.0
# 88148       ZWE    Africa     Zimbabwe  2021-05-13      38491.0       25.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 444               269.000        2721.0         8.0                8.143  ...
# 900              8331.857      125597.0       234.0              283.000  ...
# 1344               54.286        2426.0         3.0                2.857  ...
# 1788              202.286        3355.0         5.0                6.857  ...
# 2226               15.286         127.0         0.0                0.000  ...
# ...                   ...           ...         ...                  ...  ...
# 86379              92.857          35.0         0.0                0.000  ...
# 86907          680325.000     3340394.0      9135.0            12039.000  ...
# 87306              11.571        1278.0         1.0                1.857  ...
# 87728              45.143        1260.0         1.0                0.571  ...
# 88148              13.286        1582.0         3.0                1.000  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 444          1803.987              NaN                597.029
# 900               NaN              NaN                    NaN
# 1344        11803.431              1.1                304.195
# 1788        13913.839              0.5                278.364
# 2226              NaN              NaN                109.135
# ...               ...              ...                    ...
# 86379        6171.884              2.0                245.465
# 86907       15469.207             10.0                233.070
# 87306        1479.147             18.8                495.003
# 87728        3689.251             57.5                234.499
# 88148        1899.775             21.4                307.846
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 444                   9.59             NaN           NaN
# 900                    NaN             NaN           NaN
# 1344                 10.08           7.100        51.200
# 1788                  6.73           0.700        30.400
# 2226                  7.97          29.000        37.800
# ...                    ...             ...           ...
# 86379                 6.00           1.000        45.900
# 86907                 8.51           6.434        34.635
# 87306                 5.35           7.600        29.200
# 87728                 3.94           3.100        24.700
# 88148                 1.82           1.600        30.700
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 444                    37.746                       0.500            64.83
# 900                       NaN                         NaN              NaN
# 1344                      NaN                       2.890            78.57
# 1788                   83.741                       1.900            76.88
# 2226                      NaN                         NaN            83.73
# ...                       ...                         ...              ...
# 86379                  85.847                       2.600            75.40
# 86907                  60.130                       2.705            72.58
# 87306                  49.542                       0.700            66.12
# 87728                  13.938                       2.000            63.89
# 88148                  36.791                       1.700            61.49
#
#        human_development_index
# 444                      0.511
# 900                        NaN
# 1344                     0.795
# 1788                     0.748
# 2226                     0.868
# ...                        ...
# 86379                    0.704
# 86907                    0.737
# 87306                    0.470
# 87728                    0.584
# 88148                    0.571
#
# [199 rows x 59 columns]

# %%
#sorting data w.r.t total_cases
max_cases_country=last_day_cases.sort_values(by='total_cases',ascending=False)
max_cases_country
# Out:
#        iso_code      continent              location        date  total_cases  \
# 86907  OWID_WRL            NaN                 World  2021-05-13  160833004.0
# 27137  OWID_EUR            NaN                Europe  2021-05-13   46139061.0
# 4612   OWID_ASI            NaN                  Asia  2021-05-13   45352993.0
# 58534  OWID_NAM            NaN         North America  2021-05-13   38243291.0
# 84005       USA  North America         United States  2021-05-13   32852871.0
# ...         ...            ...                   ...         ...          ...
# 72347       SLB        Oceania       Solomon Islands  2021-05-13         20.0
# 85042       VUT        Oceania               Vanuatu  2021-05-13          4.0
# 50317       MHL        Oceania      Marshall Islands  2021-05-13          4.0
# 67753       WSM        Oceania                 Samoa  2021-05-13          3.0
# 51777       FSM        Oceania  Micronesia (country)  2021-05-13          1.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 86907   382131.0          680325.000     3340394.0      9135.0
# 27137    93044.0           91894.429     1046837.0      2413.0
# 4612     87155.0          408916.000      587149.0      1465.0
# 58534    54772.0           51338.286      861435.0      1271.0
# 84005    38087.0           35384.000      584487.0       802.0
# ...          ...                 ...           ...         ...
# 72347        0.0               0.000           NaN         NaN
# 85042        0.0               0.000           1.0         0.0
# 50317        0.0               0.000           NaN         NaN
# 67753        0.0               0.000           NaN         NaN
# 51777        0.0               0.000           NaN         NaN
#
#        new_deaths_smoothed  ...  gdp_per_capita  extreme_poverty  \
# 86907            12039.000  ...       15469.207             10.0
# 27137             2243.714  ...             NaN              NaN
# 4612              5029.429  ...             NaN              NaN
# 58534             1052.571  ...             NaN              NaN
# 84005              619.857  ...       54225.446              1.2
# ...                    ...  ...             ...              ...
# 72347                0.000  ...        2205.923             25.1
# 85042                0.000  ...        2921.909             13.2
# 50317                0.000  ...        3819.202              NaN
# 67753                0.000  ...        6021.557              NaN
# 51777                0.000  ...        3299.464             16.0
#
#        cardiovasc_death_rate  diabetes_prevalence  female_smokers  \
# 86907                233.070                 8.51           6.434
# 27137                    NaN                  NaN             NaN
# 4612                     NaN                  NaN             NaN
# 58534                    NaN                  NaN             NaN
# 84005                151.089                10.79          19.100
# ...                      ...                  ...             ...
# 72347                459.780                18.68             NaN
# 85042                546.300                12.02           2.800
# 50317                557.793                30.53             NaN
# 67753                348.977                 9.21          16.700
# 51777                454.343                12.02             NaN
#
#        male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 86907        34.635                  60.130                       2.705
# 27137           NaN                     NaN                         NaN
# 4612            NaN                     NaN                         NaN
# 58534           NaN                     NaN                         NaN
# 84005        24.600                     NaN                       2.770
# ...             ...                     ...                         ...
# 72347           NaN                  35.890                       1.400
# 85042        34.500                  25.209                         NaN
# 50317           NaN                  82.502                       2.700
# 67753        38.100                     NaN                         NaN
# 51777           NaN                     NaN                         NaN
#
#        life_expectancy  human_development_index
# 86907            72.58                    0.737
# 27137              NaN                      NaN
# 4612               NaN                      NaN
# 58534              NaN                      NaN
# 84005            78.86                    0.926
# ...                ...                      ...
# 72347            73.00                    0.567
# 85042            70.47                    0.609
# 50317            73.70                    0.704
# 67753            73.32                    0.715
# 51777            67.88                    0.620
#
# [199 rows x 59 columns]

# %%
#top 5 countries with maximum cases
max_cases_country[1:6]
# Out:
#        iso_code      continent        location        date  total_cases  \
# 27137  OWID_EUR            NaN          Europe  2021-05-13   46139061.0
# 4612   OWID_ASI            NaN            Asia  2021-05-13   45352993.0
# 58534  OWID_NAM            NaN   North America  2021-05-13   38243291.0
# 84005       USA  North America   United States  2021-05-13   32852871.0
# 27614  OWID_EUN            NaN  European Union  2021-05-13   31780856.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 27137    93044.0           91894.429     1046837.0      2413.0
# 4612     87155.0          408916.000      587149.0      1465.0
# 58534    54772.0           51338.286      861435.0      1271.0
# 84005    38087.0           35384.000      584487.0       802.0
# 27614    73366.0           71380.857      709429.0      1599.0
#
#        new_deaths_smoothed  ...  gdp_per_capita  extreme_poverty  \
# 27137             2243.714  ...             NaN              NaN
# 4612              5029.429  ...             NaN              NaN
# 58534             1052.571  ...             NaN              NaN
# 84005              619.857  ...       54225.446              1.2
# 27614             1512.429  ...             NaN              NaN
#
#        cardiovasc_death_rate  diabetes_prevalence  female_smokers  \
# 27137                    NaN                  NaN             NaN
# 4612                     NaN                  NaN             NaN
# 58534                    NaN                  NaN             NaN
# 84005                151.089                10.79            19.1
# 27614                    NaN                  NaN             NaN
#
#        male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 27137           NaN                     NaN                         NaN
# 4612            NaN                     NaN                         NaN
# 58534           NaN                     NaN                         NaN
# 84005          24.6                     NaN                        2.77
# 27614           NaN                     NaN                         NaN
#
#        life_expectancy  human_development_index
# 27137              NaN                      NaN
# 4612               NaN                      NaN
# 58534              NaN                      NaN
# 84005            78.86                    0.926
# 27614              NaN                      NaN
#
# [5 rows x 59 columns]

# %%
#making bar-plot for countrieswith top cases
sns.barplot(x='location',y='total_cases',data=max_cases_country[1:6],hue='location')
plt.show()

# %%
#building model

# %%
india_case.head()
# Out:
#       iso_code continent location    date  total_cases  new_cases  \
# 36268      IND      Asia    India  737454          1.0        1.0
# 36269      IND      Asia    India  737455          1.0        0.0
# 36270      IND      Asia    India  737456          1.0        0.0
# 36271      IND      Asia    India  737457          2.0        1.0
# 36272      IND      Asia    India  737458          3.0        1.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 36268                 NaN           NaN         NaN                  NaN  ...
# 36269                 NaN           NaN         NaN                  NaN  ...
# 36270                 NaN           NaN         NaN                  NaN  ...
# 36271                 NaN           NaN         NaN                  NaN  ...
# 36272                 NaN           NaN         NaN                  NaN  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 36268        6426.674             21.2                 282.28
# 36269        6426.674             21.2                 282.28
# 36270        6426.674             21.2                 282.28
# 36271        6426.674             21.2                 282.28
# 36272        6426.674             21.2                 282.28
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 36268                10.39             1.9          20.6
# 36269                10.39             1.9          20.6
# 36270                10.39             1.9          20.6
# 36271                10.39             1.9          20.6
# 36272                10.39             1.9          20.6
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 36268                   59.55                        0.53            69.66
# 36269                   59.55                        0.53            69.66
# 36270                   59.55                        0.53            69.66
# 36271                   59.55                        0.53            69.66
# 36272                   59.55                        0.53            69.66
#
#        human_development_index
# 36268                    0.645
# 36269                    0.645
# 36270                    0.645
# 36271                    0.645
# 36272                    0.645
#
# [5 rows x 59 columns]

# %%
#linear regression
from sklearn.model_selection import train_test_split

# %%
#converting string data to data-time
import datetime as dt
india_case['date']=pd.to_datetime(india_case['date'])
india_case.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#       iso_code continent location                          date  total_cases  \
# 36268      IND      Asia    India 1970-01-01 00:00:00.000737454          1.0
# 36269      IND      Asia    India 1970-01-01 00:00:00.000737455          1.0
# 36270      IND      Asia    India 1970-01-01 00:00:00.000737456          1.0
# 36271      IND      Asia    India 1970-01-01 00:00:00.000737457          2.0
# 36272      IND      Asia    India 1970-01-01 00:00:00.000737458          3.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 36268        1.0                 NaN           NaN         NaN
# 36269        0.0                 NaN           NaN         NaN
# 36270        0.0                 NaN           NaN         NaN
# 36271        1.0                 NaN           NaN         NaN
# 36272        1.0                 NaN           NaN         NaN
#
#        new_deaths_smoothed  ...  gdp_per_capita  extreme_poverty  \
# 36268                  NaN  ...        6426.674             21.2
# 36269                  NaN  ...        6426.674             21.2
# 36270                  NaN  ...        6426.674             21.2
# 36271                  NaN  ...        6426.674             21.2
# 36272                  NaN  ...        6426.674             21.2
#
#        cardiovasc_death_rate  diabetes_prevalence  female_smokers  \
# 36268                 282.28                10.39             1.9
# 36269                 282.28                10.39             1.9
# 36270                 282.28                10.39             1.9
# 36271                 282.28                10.39             1.9
# 36272                 282.28                10.39             1.9
#
#        male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 36268          20.6                   59.55                        0.53
# 36269          20.6                   59.55                        0.53
# 36270          20.6                   59.55                        0.53
# 36271          20.6                   59.55                        0.53
# 36272          20.6                   59.55                        0.53
#
#        life_expectancy  human_development_index
# 36268            69.66                    0.645
# 36269            69.66                    0.645
# 36270            69.66                    0.645
# 36271            69.66                    0.645
# 36272            69.66                    0.645
#
# [5 rows x 59 columns]

# %%
#converting date-time to ordinal
india_case['date']=india_case['date'].map(dt.datetime.toordinal)
india_case.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       iso_code continent location    date  total_cases  new_cases  \
# 36268      IND      Asia    India  719163          1.0        1.0
# 36269      IND      Asia    India  719163          1.0        0.0
# 36270      IND      Asia    India  719163          1.0        0.0
# 36271      IND      Asia    India  719163          2.0        1.0
# 36272      IND      Asia    India  719163          3.0        1.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 36268                 NaN           NaN         NaN                  NaN  ...
# 36269                 NaN           NaN         NaN                  NaN  ...
# 36270                 NaN           NaN         NaN                  NaN  ...
# 36271                 NaN           NaN         NaN                  NaN  ...
# 36272                 NaN           NaN         NaN                  NaN  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 36268        6426.674             21.2                 282.28
# 36269        6426.674             21.2                 282.28
# 36270        6426.674             21.2                 282.28
# 36271        6426.674             21.2                 282.28
# 36272        6426.674             21.2                 282.28
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 36268                10.39             1.9          20.6
# 36269                10.39             1.9          20.6
# 36270                10.39             1.9          20.6
# 36271                10.39             1.9          20.6
# 36272                10.39             1.9          20.6
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 36268                   59.55                        0.53            69.66
# 36269                   59.55                        0.53            69.66
# 36270                   59.55                        0.53            69.66
# 36271                   59.55                        0.53            69.66
# 36272                   59.55                        0.53            69.66
#
#        human_development_index
# 36268                    0.645
# 36269                    0.645
# 36270                    0.645
# 36271                    0.645
# 36272                    0.645
#
# [5 rows x 59 columns]

# %%
#getting dependent variable and indipendent variable
import numpy as np
x=np.array(india_case['date']).reshape(-1,1)
y=np.array(india_case['total_cases']).reshape(-1,1)

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
import numpy as np
lr.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
india_case.tail()
# Out:
#       iso_code continent location    date  total_cases  new_cases  \
# 36733      IND      Asia    India  719163   22662575.0   366494.0
# 36734      IND      Asia    India  719163   22992517.0   329942.0
# 36735      IND      Asia    India  719163   23340938.0   348421.0
# 36736      IND      Asia    India  719163   23703665.0   362727.0
# 36737      IND      Asia    India  719163   23703665.0        0.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 36733          391008.286      246116.0      3769.0             3879.571  ...
# 36734          387097.714      249992.0      3876.0             3940.571  ...
# 36735          382279.857      254197.0      4205.0             4001.286  ...
# 36736          375179.286      258317.0      4120.0             4021.286  ...
# 36737          316009.571      258317.0         0.0             3462.000  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 36733        6426.674             21.2                 282.28
# 36734        6426.674             21.2                 282.28
# 36735        6426.674             21.2                 282.28
# 36736        6426.674             21.2                 282.28
# 36737        6426.674             21.2                 282.28
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 36733                10.39             1.9          20.6
# 36734                10.39             1.9          20.6
# 36735                10.39             1.9          20.6
# 36736                10.39             1.9          20.6
# 36737                10.39             1.9          20.6
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 36733                   59.55                        0.53            69.66
# 36734                   59.55                        0.53            69.66
# 36735                   59.55                        0.53            69.66
# 36736                   59.55                        0.53            69.66
# 36737                   59.55                        0.53            69.66
#
#        human_development_index
# 36733                    0.645
# 36734                    0.645
# 36735                    0.645
# 36736                    0.645
# 36737                    0.645
#
# [5 rows x 59 columns]

# %%
y_pred=lr.predict(np.array(x_test).reshape(-1,1))

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(x_test,y_pred)
# Out:
# 28341865963100.94

# %%
#this model is not accurate ,will be try another algo.
